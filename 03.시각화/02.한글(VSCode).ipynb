# %% [markdown]
# ## Matplotlib 한글 사용 - VSCode

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.__version__
# Out:
# '3.7.1'

# %% [markdown]
# - 한글 설정 이전

# %%
plt.plot([0,1,4,9], label='x의 제곱')     #X는 생략 (X는 range(4)인 격, => x[0,1,2,3]), Y값만 넣은것
plt.title('라인 플롯')
plt.xlabel('x축'), plt.ylabel('y축')
plt.grid()
plt.legend()
plt.show()
# Out:
# c:\Users\human\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\human\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\human\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\human\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\human\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47215 (\N{HANGUL SYLLABLE ROS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# - 윈도우에 설치되어 있는 폰트 이용

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
plt.plot([0,1,4,9], label='x의 제곱')     #X는 생략 (X는 range(4)인 격, => x[0,1,2,3]), Y값만 넣은것
plt.title('라인 플롯')
plt.xlabel('x축'), plt.ylabel('y축')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# - 다양한 폰트를 설정하는 방법

# %%
import matplotlib.font_manager as fm
path = 'C:/Users/human/AppData/Local/Microsoft/Windows/Fonts'
font_list = fm.findSystemFonts(fontpaths=path, fontext='ttf')
font_list
# Out:
# ['C:\\Users\\human\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumMyeongjo.ttf']

# %%
f = fm.FontProperties(fname='C:/Users/human/AppData/Local/Microsoft/Windows/Fonts/NanumMyeongjo.ttf')
f.get_name()
# Out:
# 'NanumMyeongjo'

# %%
fm.fontManager.addfont(path + '/NanumMyeongjo.ttf')

# %%
plt.rcParams['font.family'] = 'NanumMyeongjo'
plt.plot([0,1,4,9], label='x의 제곱')
plt.title('라인 플롯 - 나눔명조 폰트')
plt.xlabel('x축'), plt.ylabel('y축')
plt.grid()
plt.legend()
plt.show()
