# %% [markdown]
# ## 인구소멸 위기지역 - 전처리 (Part 1)

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/시군구_성_연령_5세_별_인구2_2020.csv', encoding='euc-kr')
df.shape
# Out:
# (837, 28)

# %%
df.head(260).tail()
# Out:
#     광역시도   시군구   행정구  구분      인구수  0 - 4세  5 - 9세  10 - 14세  15 - 19세  \
# 255  경기도   수원시    소계   계  1181470   43910   56741     57093     63808
# 256  경기도   수원시    소계  남자   594380   22626   29290     29411     33178
# 257  경기도   수원시    소계  여자   587090   21284   27451     27682     30630
# 258  경기도   수원시   장안구   계   273908    7659   11548     13483     16100
# 259  경기도   수원시   장안구  남자   137852    3904    6034      6954      8498
#
#      20 - 24세  ...  65 - 69세  70 - 74세  75 - 79세  80세 이상  80 - 84세  85세 이상  \
# 255     86365  ...     43315     31267     23774   27796     16028   11768
# 256     44785  ...     20789     14491     10013    9142      5900    3242
# 257     41581  ...     22527     16776     13761   18654     10129    8526
# 258     22511  ...     11311      8549      6870    8443      4806    3637
# 259     12166  ...      5418      3905      2892    2846      1819    1027
#
#      85 - 89세  90 - 94세  95 - 99세  100세 이상
# 255      8044      2957       671       96
# ...

# %%
df.head(10)
# Out:
#     광역시도   시군구  행정구  구분       인구수   0 - 4세   5 - 9세  10 - 14세  15 - 19세  \
# 0     전국    소계  NaN   계  51349259  1760638  2305389   2314984   2551013
# 1     전국    소계  NaN  남자  25606081   903178  1182551   1192977   1325906
# 2     전국    소계  NaN  여자  25743179   857460  1122838   1122008   1225107
# 3  서울특별시    소계  NaN   계   9533412   285507   356876    369851    427350
# 4  서울특별시    소계  NaN  남자   4642653   146912   182974    190281    219321
# 5  서울특별시    소계  NaN  여자   4890760   138596   173902    179570    208030
# 6  서울특별시   종로구  NaN   계    144866     3309     4549      5120      6182
# 7  서울특별시   종로구  NaN  남자     70613     1668     2297      2575      3099
# 8  서울특별시   종로구  NaN  여자     74253     1641     2252      2545      3083
# 9  서울특별시    중구  NaN   계    121520     3483     3611      3093      3869
#
#    20 - 24세  ...  65 - 69세  70 - 74세  75 - 79세   80세 이상  80 - 84세  85세 이상  \
# 0   3272265  ...   2635592   2000709   1602663  1895712   1110912  784800
# ...

# %%
# 행정구가 있으면 시군구 값을 행정구 값으로 변경
df.시군구[df.행정구.notnull()] = df.행정구[df.행정구.notnull()]
df.head(260).tail()
# Out:
#     광역시도   시군구   행정구  구분      인구수  0 - 4세  5 - 9세  10 - 14세  15 - 19세  \
# 255  경기도    소계    소계   계  1181470   43910   56741     57093     63808
# 256  경기도    소계    소계  남자   594380   22626   29290     29411     33178
# 257  경기도    소계    소계  여자   587090   21284   27451     27682     30630
# 258  경기도   장안구   장안구   계   273908    7659   11548     13483     16100
# 259  경기도   장안구   장안구  남자   137852    3904    6034      6954      8498
#
#      20 - 24세  ...  65 - 69세  70 - 74세  75 - 79세  80세 이상  80 - 84세  85세 이상  \
# 255     86365  ...     43315     31267     23774   27796     16028   11768
# 256     44785  ...     20789     14491     10013    9142      5900    3242
# 257     41581  ...     22527     16776     13761   18654     10129    8526
# 258     22511  ...     11311      8549      6870    8443      4806    3637
# 259     12166  ...      5418      3905      2892    2846      1819    1027
#
#      85 - 89세  90 - 94세  95 - 99세  100세 이상
# 255      8044      2957       671       96
# ...

# %%
# 소계 데이터 지우기 (필터링)
df = df[df.시군구 != '소계']
df.head()
# Out:
#      광역시도   시군구  행정구  구분     인구수  0 - 4세  5 - 9세  10 - 14세  15 - 19세  \
# 6   서울특별시   종로구  NaN   계  144866    3309    4549      5120      6182
# 7   서울특별시   종로구  NaN  남자   70613    1668    2297      2575      3099
# 8   서울특별시   종로구  NaN  여자   74253    1641    2252      2545      3083
# 9   서울특별시    중구  NaN   계  121520    3483    3611      3093      3869
# 10  서울특별시    중구  NaN  남자   59536    1772    1852      1550      1976
#
#     20 - 24세  ...  65 - 69세  70 - 74세  75 - 79세  80세 이상  80 - 84세  85세 이상  \
# 6      10602  ...      7637      6245      5450    6265      3682    2583
# 7       4976  ...      3744      2842      2369    2406      1517     889
# 8       5627  ...      3893      3403      3081    3859      2165    1694
# 9       7605  ...      6872      5475      4501    5030      2904    2126
# 10      3543  ...      3380      2523      1943    1754      1125     629
#
#     85 - 89세  90 - 94세  95 - 99세  100세 이상
# 6       1749       639       169       26
# ...

# %%
# 20~39세, 65세 이상 컬럼 만들기
df['20-39세'] = df['20 - 24세'] + df['25 - 29세'] + df['30 - 34세'] + df['35 - 39세']
df['65세 이상'] = df['65 - 69세'] + df['70 - 74세'] + df['75 - 79세'] + df['80세 이상']

# %%
# 필요한 컬럼 추출
df = df[['광역시도', '시군구', '구분', '인구수', '20-39세' ,'65세 이상']]
print(df.shape)
df.head()
# Out:
# (750, 6)
#      광역시도   시군구  구분     인구수  20-39세  65세 이상
# 6   서울특별시   종로구   계  144866   43061   25597
# 7   서울특별시   종로구  남자   70613   21327   11361
# 8   서울특별시   종로구  여자   74253   21736   14236
# 9   서울특별시    중구   계  121520   38455   21878
# 10  서울특별시    중구  남자   59536   18864    9600

# %%
# 테이블 정리
pop = pd.pivot_table(df,
                     index=['광역시도', '시군구'],
                     columns=['구분'],
                     values=['인구수', '20-39세', '65세 이상'])
pop.head()
# Out:
#           20-39세               65세 이상                   인구수
# 구분             계     남자     여자      계     남자     여자       계      남자      여자
# 광역시도 시군구
# 강원도   강릉시  47006  25199  21807  43830  18604  25227  211643  105025  106618
#       고성군   5217   3175   2042   7755   3237   4519   26792   13864   12928
#       동해시  18727  10469   8258  17572   7624   9949   89814   45572   44242
#       삼척시  13583   7469   6117  16077   6766   9311   65623   33275   32348
#       속초시  18080   9909   8171  15170   6345   8826   81497   40312   41185

# %%
# 인구 소멸비율 계산
pop['소멸비율'] = round(pop['20-39세', '여자'] / pop['65세 이상', '계'], 4) #소숫점 4자리까지
pop.head()
# Out:
#           20-39세               65세 이상                   인구수                  \
# 구분             계     남자     여자      계     남자     여자       계      남자      여자
# 광역시도 시군구
# 강원도   강릉시  47006  25199  21807  43830  18604  25227  211643  105025  106618
#       고성군   5217   3175   2042   7755   3237   4519   26792   13864   12928
#       동해시  18727  10469   8258  17572   7624   9949   89814   45572   44242
#       삼척시  13583   7469   6117  16077   6766   9311   65623   33275   32348
#       속초시  18080   9909   8171  15170   6345   8826   81497   40312   41185
#
#              소멸비율
# 구분
# 광역시도 시군구
# 강원도   강릉시  0.4975
#       고성군  0.2633
#       동해시  0.4700
#       삼척시  0.3805
#       속초시  0.5386

# %%
# 소멸위기지역, 소멸위기고위험지역
pop['소멸위기지역'] = pop['소멸비율'] < 0.5
pop['소멸위기고위험지역'] = pop['소멸비율'] < 0.2
pop.head()
# Out:
#           20-39세               65세 이상                   인구수                  \
# 구분             계     남자     여자      계     남자     여자       계      남자      여자
# 광역시도 시군구
# 강원도   강릉시  47006  25199  21807  43830  18604  25227  211643  105025  106618
#       고성군   5217   3175   2042   7755   3237   4519   26792   13864   12928
#       동해시  18727  10469   8258  17572   7624   9949   89814   45572   44242
#       삼척시  13583   7469   6117  16077   6766   9311   65623   33275   32348
#       속초시  18080   9909   8171  15170   6345   8826   81497   40312   41185
#
#              소멸비율 소멸위기지역 소멸위기고위험지역
# 구분
# 광역시도 시군구
# 강원도   강릉시  0.4975   True     False
#       고성군  0.2633   True     False
#       동해시  0.4700   True     False
#       삼척시  0.3805   True     False
#       속초시  0.5386  False     False

# %%
# 인구소멸 위기지역
cirsis_region = pop[pop.소멸위기지역].index.get_level_values(1)
len(cirsis_region), cirsis_region[:5]
# Out:
# (102,
#  Index([' 강릉시', ' 고성군', ' 동해시', ' 삼척시', ' 양구군'], dtype='object', name='시군구'))

# %%
# 인구소멸 고위험지역
high_cirsis_region = pop[pop.소멸위기고위험지역].index.get_level_values(1)
len(high_cirsis_region), high_cirsis_region[:5]
# Out:
# (22,
#  Index([' 남해군', ' 산청군', ' 의령군', ' 하동군', ' 합천군'], dtype='object', name='시군구'))

# %%
# 컬럼명 변경 : 이중 인덱스 --> 단일 인덱스
pop.columns.get_level_values(0)
# Out:
# Index(['20-39세', '20-39세', '20-39세', '65세 이상', '65세 이상', '65세 이상', '인구수',
#        '인구수', '인구수', '소멸비율', '소멸위기지역', '소멸위기고위험지역'],
#       dtype='object')

# %%
pop.columns.get_level_values(1)
# Out:
# Index(['계', '남자', '여자', '계', '남자', '여자', '계', '남자', '여자', '', '', ''], dtype='object', name='구분')

# %%
new_columns = []
for i in range(len(pop.columns.get_level_values(0))):
    new_columns.append(pop.columns.get_level_values(0)[i]+pop.columns.get_level_values(1)[i])
pop.columns = new_columns
pop.head(3)
# Out:
#            20-39세계  20-39세남자  20-39세여자  65세 이상계  65세 이상남자  65세 이상여자    인구수계  \
# 광역시도 시군구
# 강원도   강릉시    47006     25199     21807    43830     18604     25227  211643
#       고성군     5217      3175      2042     7755      3237      4519   26792
#       동해시    18727     10469      8258    17572      7624      9949   89814
#
#             인구수남자   인구수여자    소멸비율  소멸위기지역  소멸위기고위험지역
# 광역시도 시군구
# 강원도   강릉시  105025  106618  0.4975    True      False
#       고성군   13864   12928  0.2633    True      False
#       동해시   45572   44242  0.4700    True      False

# %%
# 65세 이상남자, 65세 이상여자, 인구수남자,	인구수여자 컬럼 제거
pop.drop(columns=['65세 이상남자', '65세 이상여자', '인구수남자', '인구수여자'], inplace=True)
pop.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\WorkSpace\02.DataAnalysis\10.Cartogram\01.인구소멸위기지역-전처리.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell:/d%3A/WorkSpace/02.DataAnalysis/10.Cartogram/01.%EC%9D%B8%EA%B5%AC%EC%86%8C%EB%A9%B8%EC%9C%84%EA%B8%B0%EC%A7%80%EC%97%AD-%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> # 65세 이상남자, 65세 이상여자, 인구수남자,	인구수여자 컬럼 제거
# ----> <a href='vscode-notebook-cell:/d%3A/WorkSpace/02.DataAnalysis/10.Cartogram/01.%EC%9D%B8%EA%B5%AC%EC%86%8C%EB%A9%B8%EC%9C%84%EA%B8%B0%EC%A7%80%EC%97%AD-%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> pop.drop(columns=['65세 이상남자', '65세 이상여자', '인구수남자', '인구수여자'], inplace=True)
# ...

# %%
# 인덱스 제거
pop.reset_index(inplace=True)
pop.head(3)
# Out:
#   광역시도   시군구  20-39세계  20-39세남자  20-39세여자  65세 이상계    인구수계    소멸비율  소멸위기지역  \
# 0  강원도   강릉시    47006     25199     21807    43830  211643  0.4975    True
# 1  강원도   고성군     5217      3175      2042     7755   26792  0.2633    True
# 2  강원도   동해시    18727     10469      8258    17572   89814  0.4700    True
#
#    소멸위기고위험지역
# 0      False
# 1      False
# 2      False

# %%
# 시군구 공백 제거
pop.시군구 = pop.시군구.str.strip()

# %%
# 파일 저장
pop.to_csv('data/시군구_전처리완료.csv', encoding='euc-kr', index=False)
